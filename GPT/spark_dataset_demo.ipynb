# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("VSCodeTest") \
    .master("local[*]") \
    .getOrCreate()

print("✅ Spark session running in VS Code!")
print("Spark version:", spark.version)
# Out:
# ✅ Spark session running in VS Code!
# Spark version: 4.0.0

# %%
import time
import json
from typing import Optional
from openai import OpenAI
from IPython.display import Markdown, display


# Connect to your local Ollama server
client = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama"  # Dummy key required by SDK
)

# %%
# --- Setup ---
conversation_log = []
chat_memory = []

def ask_local_gpt(
    prompt: str,
    model: str = "gpt-oss:20b",
    system_message: Optional[str] = None,
    render_markdown: bool = True,
    verbose: bool = False,
    return_raw: bool = False,
    reset_chat: bool = False,
    show_history: bool = False,
    stream_response: bool = True,
    reasoning_mode: bool = False,
    json_mode: bool = False,  # <-- new flag!
    structured_return: bool = False  # <-- NEW!
) -> Optional[str]:
    """
    Query a local GPT model via Ollama, with support for step-by-step reasoning (Scratchpad).
    If json_mode is True, the model is instructed to respond in JSON, and results are parsed accordingly.

    Args:
        prompt (str): The user’s input/question.
        ...
        json_mode (bool): If True, instructs the LLM to return a JSON object with 'thoughts' and 'answer'.
    Returns:
        str or None: Clean final answer or full output, depending on flags.
    """
    global chat_memory, conversation_log

    try:
        if reset_chat:
            chat_memory = []

        # -- Prompt setup --
        if json_mode:
            sys_prompt = (
                "You are a helpful assistant. "
                "For every question, reply ONLY in this exact JSON format: "
                "{\"thoughts\": \"<step-by-step reasoning>\", \"answer\": \"<final answer only>\"} "
                "Do not include any extra commentary, code fences, or markdown—just the JSON."
            )
            chat_memory = [{"role": "system", "content": sys_prompt}]
            full_prompt = prompt
        else:
            # Normal or reasoning mode (old logic)
            default_reasoning_prompt = (
                "You are a helpful assistant that always reasons step by step before giving an answer. "
                "First, think through the problem, then provide a clear final answer."
            )
            if not any(m.get("role") == "system" for m in chat_memory):
                chat_memory.insert(0, {
                    "role": "system",
                    "content": system_message or (default_reasoning_prompt if reasoning_mode else "")
                })
            if reasoning_mode:
                full_prompt = (
                    f"### Scratchpad:\n"
                    f"The user asked: \"{prompt.strip()}\"\n"
                    f"Think step-by-step and reason before answering.\n\n"
                    f"### Final Answer:\n"
                )
            else:
                full_prompt = prompt

        chat_memory.append({"role": "user", "content": full_prompt})
        start = time.time()

        # --- Get response (streamed or not) ---
        if stream_response:
            print("🤔 Thinking...\n")
            stream = client.chat.completions.create(
                model=model,
                messages=chat_memory,
                stream=True
            )
            tokens = []
            for chunk in stream:
                delta = chunk.choices[0].delta.content or ""
                print(delta, end="", flush=True)
                tokens.append(delta)
            print()
            assistant_reply = "".join(tokens)
        else:
            response = client.chat.completions.create(
                model=model,
                messages=chat_memory
            )
            assistant_reply = response.choices[0].message.content

        chat_memory.append({"role": "assistant", "content": assistant_reply})

        # --- Parse output ---
        thoughts, final_answer = "", assistant_reply.strip()
        if json_mode:
            # Try to parse first valid JSON block in reply
            try:
                start_idx = assistant_reply.find('{')
                end_idx = assistant_reply.rfind('}') + 1
                if start_idx == -1 or end_idx == -1:
                    raise ValueError("No JSON object detected in model reply.")
                data = json.loads(assistant_reply[start_idx:end_idx])
                thoughts = data.get("thoughts", "").strip()
                final_answer = data.get("answer", "").strip()
            except Exception as e:
                print("❌ Failed to parse model JSON output:", e)
                thoughts = ""
                final_answer = assistant_reply.strip()
        else:
            # fallback: regex/extraction (from your original, see above)
            import re
            scratchpad_match = re.search(
                r"### Scratchpad:\s*(.*?)### Final Answer:",
                assistant_reply,
                re.DOTALL | re.IGNORECASE
            )
            final_answer_match = re.search(
                r"### Final Answer:\s*([\s\S]*?)(?:$|\n#|\n\n)",
                assistant_reply,
                re.DOTALL | re.IGNORECASE
            )
            if scratchpad_match:
                thoughts = scratchpad_match.group(1).strip()
            if final_answer_match:
                final_answer = final_answer_match.group(1).strip()

        # --- Log results ---
        conversation_log.append({
            "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
            "prompt": prompt,
            "thoughts": thoughts,
            "answer": final_answer,
            "raw": assistant_reply
        })

        # --- Output control ---
        if structured_return:
            return {
                "thoughts": thoughts,
                "answer": final_answer,
                "raw": assistant_reply
            }
        elif return_raw:
            return assistant_reply
        elif render_markdown:
            display(Markdown(final_answer))
        elif verbose:
            print("\n🧼 Clean answer:\n", final_answer)
        else:
            return final_answer

        if verbose:
            print(f"\n✅ Response time: {round(time.time() - start, 2)}s")

        if show_history:
            print("\n📜 Message History:")
            for msg in chat_memory:
                print(f"{msg['role'].upper()}: {msg['content']}\n")

        return final_answer if verbose else None

    except Exception as e:
        print("❌ Error in ask_local_gpt:", str(e))
        return "Error occurred."

# %%
ask_local_gpt(
    "what are the top 10 dogs for new couples. Number them from 1 to 10 and explain why each is a good choice.",
    stream_response=True,
    reasoning_mode=True,
    json_mode=True
)
# Out:
# 🤔 Thinking...
#
# {"thoughts":"User requested a list of top 10 dog breeds suitable for new couples, numbered 1 through 10, with brief explanations. Provide answer in plain text list within JSON \"answer\" field, no markdown or extraneous text.","answer":"1. Labrador Retriever – Friendly, trainable, and great with newcomers. 2. Cavalier King Charles Spaniel – Small, affectionate and low energy. 3. Golden Retriever – Gentle, loyal, and excellent for active couples. 4. Australian Shepherd – Intelligent, energetic, and pair well with couples who enjoy hiking. 5. French Bulldog – Low maintenance, short‑lived, and great indoor companions. 6. Bichon Frise – Hypoallergenic, playful, and easy to groom. 7. Shih Tzu – Compact, affectionate, and suited to apartment life. 8. Border Collie – Highly intelligent, ideal for couples who can give plenty of exercise. 9. Collie – Calm, friendly, and adaptable to various living environments. 10. Boxer – Playful, protective, and great for families starting out. "}
# 1. Labrador Retriever – Friendly, trainable, and great with newcomers. 2. Cavalier King Charles Spaniel – Small, affectionate and low energy. 3. Golden Retriever – Gentle, loyal, and excellent for active couples. 4. Australian Shepherd – Intelligent, energetic, and pair well with couples who enjoy hiking. 5. French Bulldog – Low maintenance, short‑lived, and great indoor companions. 6. Bichon Frise – Hypoallergenic, playful, and easy to groom. 7. Shih Tzu – Compact, affectionate, and suited to apartment life. 8. Border Collie – Highly intelligent, ideal for couples who can give plenty of exercise. 9. Collie – Calm, friendly, and adaptable to various living environments. 10. Boxer – Playful, protective, and great for families starting out.

# %%
import pandas as pd

# %% [markdown]
# ## Batch Questions in structured format

# %%
results = []
questions = [
    "what are the top 10 dogs for new couples",
    "what are the top 5 cats for families",
    "what are the best 3 fish for beginners and what are their care requirements",
    "what are the top 5 birds for small apartments",
    # ... more prompts
]
for q in questions:
    res = ask_local_gpt(q, stream_response=True, reasoning_mode=True, json_mode=True, structured_return=True)
    res["prompt"] = q  # Optionally add prompt to output
    results.append(res)

df = pd.DataFrame(results)
# Out:
# 🤔 Thinking...
#
# {"thoughts":"Identify qualities important for couples (friendly, low-maintenance, good bond, adaptable). Select breeds known for those traits. Prioritize medium to small with easy grooming, low aggression, good with partners. List top 10 accordingly.","answer":"1. Labrador Retriever\n2. Golden Retriever\n3. Cavalier King Charles Spaniel\n4. French Bulldog\n5. Poodle (Miniature)\n6. Bichon Frise\n7. Boston Terrier\n8. Shih Tzu\n9. Beagle\n10. Cocker Spaniel"}
# 🤔 Thinking...
#
# {"thoughts":"Identify breeds known for family-friendly traits: sociability, low aggression, good with kids, adaptable. Common recommendations are Ragdoll, Maine Coon, British Shorthair, Burmese, and Siamese. Format the answer as a numbered list for clarity.", "answer":"1. Ragdoll – calm, affectionate, loves cuddles.\n2. Maine Coon – gentle, friendly, playful.\n3. British Shorthair – easygoing, tolerant, low maintenance.\n4. Burmese – social, energetic, loves family.\n5. Siamese – vocal, interactive, good with children."}
# 🤔 Thinking...
#
# {"thoughts":"Selecting beginner fish requires considering tank size, temperature, maintenance, compatibility, and diet. Focus on species that tolerate a range, do not need sophisticated setups, and are hardy. Betta, Guppies, Neon Tetras are classic choices. The care summary covers tank size, temp, pH, diet, and tankmate advice.","answer":"1. Betta fish – 5‑glb tank, 28–30°C (78–84°F), soft to slightly acidic water (pH 5.5–7.0), diet: high‑quality betta pellets or frozen bloodworms, no tankmates unless male‑to‑female or community‑compatible bettas.\n2. Guppies – 10‑gal minimum tank, 22–26°C (72–79°F), neutral pH 7.0–7.8, feed flake food plus occasional frozen or fresh foods, breed readily.\n3. Neon tetras – 20‑gal tank, 22–26°C (72–79°F), slightly acidic pH 6.5–7.5, feed flakes, live or frozen brine shrimp, schooling fish, avoid large or aggressive tankmates."}
# 🤔 Thinking...
#
# {"thoughts":"I need to output a list of 5 birds suitable for small apartments, ensuring they’re small, relatively quiet, low-maintenance, and can thrive in limited space. Common options include budgies, cockatiels, lovebirds, canaries, and parrotlets. I’ll list them with a brief note on suitability. I must adhere to the dev instruction: output only a JSON with \"thoughts\" and \"answer\" fields, no markdown or extra commentary.","answer":"1. Budgie (Budgerigar) – Small, friendly, and gentle voices.\n2. Cockatiel – Moderate size, great companionship, and relatively quiet.\n3. Lovebird – Compact, sociable, and good for tight spaces.\n4. Canary – Small, peaceful singers, minimal cage requirements.\n5. Parrotlet – Tiny, energetic, perfect for compact apartments."}

# %%
df
# Out:
#                                             thoughts  \
# 0  Identify qualities important for couples (frie...
# 1  Identify breeds known for family-friendly trai...
# 2  Selecting beginner fish requires considering t...
# 3  I need to output a list of 5 birds suitable fo...
#
#                                               answer  \
# 0  1. Labrador Retriever\n2. Golden Retriever\n3....
# 1  1. Ragdoll – calm, affectionate, loves cuddles...
# 2  1. Betta fish – 5‑glb tank, 28–30°C (78–84°F),...
# 3  1. Budgie (Budgerigar) – Small, friendly, and ...
#
#                                                  raw  \
# 0  {"thoughts":"Identify qualities important for ...
# 1  {"thoughts":"Identify breeds known for family-...
# 2  {"thoughts":"Selecting beginner fish requires ...
# 3  {"thoughts":"I need to output a list of 5 bird...
#
#                                               prompt
# 0           what are the top 10 dogs for new couples
# 1               what are the top 5 cats for families
# 2  what are the best 3 fish for beginners and wha...
# 3      what are the top 5 birds for small apartments

# %% [markdown]
# ## Showing the difference between the chat log and the structured format

# %%
df_log = pd.DataFrame(conversation_log)
df_log.to_csv("chat_log.csv", index=False)

# %%
df_log
# Out:
#              timestamp                                             prompt  \
# 0  2025-08-07 00:16:13  what are the top 10 dogs for new couples. Numb...
# 1  2025-08-07 00:17:09           what are the top 10 dogs for new couples
# 2  2025-08-07 00:18:05               what are the top 5 cats for families
# 3  2025-08-07 00:20:04  what are the best 3 fish for beginners and wha...
# 4  2025-08-07 00:20:52      what are the top 5 birds for small apartments
#
#                                             thoughts  \
# 0  I need to list the top 10 dog breeds that are ...
# 1  Identify qualities important for couples (frie...
# 2  Identify breeds known for family-friendly trai...
# 3  Selecting beginner fish requires considering t...
# 4  I need to output a list of 5 birds suitable fo...
#
#                                               answer  \
# 0  1. Labrador Retriever – Friendly, easy to trai...
# 1  1. Labrador Retriever\n2. Golden Retriever\n3....
# 2  1. Ragdoll – calm, affectionate, loves cuddles...
# 3  1. Betta fish – 5‑glb tank, 28–30°C (78–84°F),...
# 4  1. Budgie (Budgerigar) – Small, friendly, and ...
#
#                                                  raw
# 0  {"thoughts":"I need to list the top 10 dog bre...
# 1  {"thoughts":"Identify qualities important for ...
# 2  {"thoughts":"Identify breeds known for family-...
# 3  {"thoughts":"Selecting beginner fish requires ...
# 4  {"thoughts":"I need to output a list of 5 bird...

# %% [markdown]
# ## Sample DF

# %%
import pandas as pd

df = pd.DataFrame({
    "product_id": [101, 102, 103, 104, 105, 106, 107],
    "description": [
        "Black lace-up sneakers with a memory foam sole.",
        "Elegant silver necklace with a heart pendant.",
        "Bluetooth noise-cancelling over-ear headphones.",
        "Organic cotton t-shirt in various colors.",
        "Stainless steel water bottle with a flip-top lid.",
        "Samsung Galaxy S21 smartphone with 128GB storage.",
        "Wireless ergonomic mouse with customizable buttons."
    ]
})

# %% [markdown]
# ## Leveraging the LLM to add a column based on the description in our dataframe

# %%
import pandas as pd
from tqdm.auto import tqdm

def annotate_column_with_llm(
    df: pd.DataFrame,
    prompt_template: str,
    target_column: str,
    context_column: str,
    gpt_kwargs: dict = None,
    json_mode: bool = True,
    reasoning_column: str = None
):
    """
    Annotate a DataFrame using the answer/reasoning fields returned by ask_local_gpt(structured_return=True).
    """
    gpt_kwargs = gpt_kwargs or {}

    outputs = []
    reasonings = []
    for idx, row in tqdm(df.iterrows(), total=len(df)):
        prompt = prompt_template.format(context=row[context_column])
        res = ask_local_gpt(
            prompt,
            json_mode=json_mode,
            render_markdown=False,
            structured_return=True,  # <--- The magic!
            **gpt_kwargs
        )
        value = res.get("answer") if res else None
        thoughts = res.get("thoughts") if res else None
        print(value)
        outputs.append(value)
        reasonings.append(thoughts)
    df[target_column] = outputs
    if reasoning_column:
        df[reasoning_column] = reasonings
    return df

# %%
annotate_column_with_llm(
    df,
    prompt_template="Assign a broad product category (shoes, jewelry, electronics, etc) for: {context}\nAlso explain your reasoning.",
    target_column="category",
    context_column="description",
    reasoning_column="category_reasoning"
)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# 🤔 Thinking...
#
# {"thoughts":"The product described is a pair of sneakers, which are a type of footwear. Sneakers are commonly classified under the broad category of shoes, as they are a style of shoes designed for casual wear or athletic use. The mention of a memory foam sole and black lace-up design reinforces that it is a shoe, not a separate category like apparel or accessories. Therefore the appropriate broad product category is Shoes.","answer":"Shoes"}
# Shoes
# 🤔 Thinking...
#
# {"thoughts":"1. Identify what the item is: a necklace made of silver with a heart pendant. 2. Determine the broader category that includes necklaces. 3. Jewelry is the standard category for necklaces, rings, bracelets, earrings, etc. 4. So the appropriate broad product category is Jewelry.","answer":"jewelry"}
# jewelry
# 🤔 Thinking...
#
# {"thoughts":"First, identify the main function of the item: the headphones produce audio and have active noise cancellation, both technical features that involve electronic components.\nNext, consider common retail categories for such gadgets. In typical e‑commerce and retail classification, listening devices with Bluetooth connectivity are grouped under electronics/ audio equipment.\nThus the most appropriate broad category is electronics.\n\nAnswer is electronics.","answer":"electronics"}
# electronics
# 🤔 Thinking...
#
# {"thoughts":"The item is an organic cotton t‑shirt available in various colors. It is made of fabric and worn on the body, which places it in the apparel or clothing category. This is a broad product classification like shoes, jewelry, electronics, etc., but specifically relates to garments. Therefore the appropriate broad category is clothing (apparel).","answer":"Clothing"}
# Clothing
# 🤔 Thinking...
#
# {"thoughts":"1. Identify the primary function of the item: a reusable container for liquids.\n2. Determine the material: stainless steel, which is common for durable beverage containers.\n3. Consider typical retail classification: beverage containers such as water bottles, tumblers, and mugs are usually grouped under a kitchen or beverage category.\n4. Choose a broad category that encompasses water bottles: 'Kitchen & Dining' is a common umbrella for drinkware.\n5. Provide the final category accordingly.","answer":"Kitchen & Dining"}
# Kitchen & Dining
# 🤔 Thinking...
#
# {"thoughts":"1. Identify the item: Samsung Galaxy S21 smartphone with 128GB storage. 2. Determine the type of product: It is a mobile device used for communication, media, applications, etc. 3. Classify it into broad categories: It does not fit into clothing, accessories, jewelry, books, or other non-electronic categories. 4. The appropriate broad category is Electronics, which includes devices like smartphones, tablets, and computers.", "answer":"Electronics"}
# Electronics
# 🤔 Thinking...
#
# {"thoughts":"The product is a computer peripheral that uses wireless connectivity and offers ergonomic design with customizable buttons. It belongs to the electronics sector because it contains electronic components, requires power, and functions as a device used with computers. It’s not classified under furniture, clothing, accessories or other categories, so the most appropriate broad category is Electronics.","answer":"Electronics"}
# Electronics
#    product_id                                        description  \
# 0         101    Black lace-up sneakers with a memory foam sole.
# 1         102      Elegant silver necklace with a heart pendant.
# 2         103    Bluetooth noise-cancelling over-ear headphones.
# 3         104          Organic cotton t-shirt in various colors.
# 4         105  Stainless steel water bottle with a flip-top lid.
# 5         106  Samsung Galaxy S21 smartphone with 128GB storage.
# 6         107  Wireless ergonomic mouse with customizable but...
#
#            category                                 category_reasoning
# 0             Shoes  The product described is a pair of sneakers, w...
# 1           jewelry  1. Identify what the item is: a necklace made ...
# 2       electronics  First, identify the main function of the item:...
# 3          Clothing  The item is an organic cotton t‑shirt availabl...
# 4  Kitchen & Dining  1. Identify the primary function of the item: ...
# 5       Electronics  1. Identify the item: Samsung Galaxy S21 smart...
# 6       Electronics  The product is a computer peripheral that uses...

# %%
spark.stop()
