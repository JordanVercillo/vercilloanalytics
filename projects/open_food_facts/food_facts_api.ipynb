# %%
import requests
import pandas as pd

def fetch_products(query, query_type="search", page_size=100, page=1, sort_by="created_t"):

    if query_type == "brand":
        # Brand-based search
        url = f"https://world.openfoodfacts.org/brand/{query}.json"
        params = {
            "page_size": page_size,
            "page": page,
            "sort_by": sort_by
        }
    else:
        # Search term-based search
        url = "https://world.openfoodfacts.org/cgi/search.pl"
        params = {
            "search_terms": query,
            "search_simple": 1,
            "action": "process",
            "json": 1,
            "page_size": page_size,
            "page": page,
            "sort_by": sort_by
        }

    response = requests.get(url, params=params)
    if response.status_code != 200:
        raise Exception(f"API request failed: {response.status_code}")

    data = response.json()
    return data.get("products", [])

def extract_product_fields(product):
    nutriments = product.get("nutriments", {})
    return {
        # Identifiers
        "product_name": product.get("product_name", "N/A"),
        "brands": product.get("brands", "N/A"),
        "barcode": product.get("code", "N/A"),
        "categories": ", ".join(product.get("categories_tags", [])),
        "countries": ", ".join(product.get("countries_tags", [])),
        "image_url": product.get("image_url", "N/A"),
        "ingredients_text": product.get("ingredients_text", "N/A"),

        # Nutrition values
        "energy_kcal_100g": nutriments.get("energy-kcal_100g"),
        "fat_100g": nutriments.get("fat_100g"),
        "saturated_fat_100g": nutriments.get("saturated-fat_100g"),
        "carbohydrates_100g": nutriments.get("carbohydrates_100g"),
        "sugars_100g": nutriments.get("sugars_100g"),
        "fiber_100g": nutriments.get("fiber_100g"),
        "proteins_100g": nutriments.get("proteins_100g"),
        "salt_100g": nutriments.get("salt_100g"),

        # Nutrition grade and labels
        "nutrition_grade": product.get("nutrition_grades_tags", [None])[0],
        "nova_group": product.get("nova_group"),
        "ecoscore_grade": product.get("ecoscore_grade"),
        "labels": ", ".join(product.get("labels_tags", [])),
        "allergens": ", ".join(product.get("allergens_tags", [])),
        "packaging": ", ".join(product.get("packaging_tags", [])),

        # Timestamps
        "created_t": product.get("created_t"),
        "last_modified_t": product.get("last_modified_t"),
    }

def search_and_extract_all(query, query_type="search", page_size=100, sort_by="created_t", max_pages=None):

    all_records = []
    page = 1

    while True:
        print(f"Fetching page {page}...")
        products = fetch_products(query, query_type=query_type, page_size=page_size, page=page, sort_by=sort_by)

        if not products:
            print("No more products found.")
            break

        for product in products:
            record = extract_product_fields(product)
            all_records.append(record)

        if max_pages is not None and page >= max_pages:
            print("Reached max_pages limit.")
            break

        page += 1

    df = pd.DataFrame(all_records)
    return df

# %%
df_oreo = search_and_extract_all("oreo", query_type="brand")
# Out:
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# No more products found.

# %%
df_oreo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715 entries, 0 to 714
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_name        715 non-null    object
#  1   brands              715 non-null    object
#  2   barcode             715 non-null    object
#  3   categories          715 non-null    object
#  4   countries           715 non-null    object
#  5   image_url           715 non-null    object
#  6   ingredients_text    715 non-null    object
#  7   energy_kcal_100g    598 non-null    float64
#  8   fat_100g            603 non-null    float64
#  9   saturated_fat_100g  588 non-null    float64
#  10  carbohydrates_100g  603 non-null    float64
#  11  sugars_100g         591 non-null    float64
#  12  fiber_100g          371 non-null    float64
#  13  proteins_100g       601 non-null    float64
#  14  salt_100g           578 non-null    float64
#  15  nutrition_grade     715 non-null    object
#  16  nova_group          293 non-null    float64
#  17  ecoscore_grade      0 non-null      object
#  18  labels              715 non-null    object
#  19  allergens           715 non-null    object
#  20  packaging           715 non-null    object
#  21  created_t           715 non-null    int64
#  22  last_modified_t     715 non-null    int64
# dtypes: float64(9), int64(2), object(12)
# memory usage: 128.6+ KB

# %%
# df_oreo_original = df_oreo[df_oreo["product_name"].str.lower() == "oreo original"]

df_oreo_canada = df_oreo[df_oreo["countries"].str.contains("en:canada", na=False)]

df_oreo_canada
# Out:
#                            product_name         brands        barcode  \
# 16                    Oreo Selena Gomez           Oreo  0066721029621
# 26            Sesame Flavored Thin Oreo           Oreo  6901668939562
# 52                   Peanut Butter Oreo           Oreo  0066721029706
# 119                           thin oreo           Oreo  0066721028990
# 137                     Oreo à l'érable           Oreo  0066721028921
# 165                         Golden oreo           Oreo  0066721028099
# 174                    The Orginal Oreo           Oreo  0066721028105
# 190                Oreo, double stuffed           Oreo  0066721028082
# 214                                Oreo           Oreo  0066721009555
# 231                                Oreo           Oreo  0066721027627
# 290                             Biscuit           Oreo  0066721026880
# 296  Hace crème saveur de chocolat noir           Oreo  0066721026668
# 323     Biscuits-sandwiches au chocolat           Oreo  0066721025708
# 674                            Original  Oreo,Mondelēz  7622300744663
# 712                       Original Oreo           Oreo  8410000810004
#
#                                             categories  \
# 16
# 26
# 52
# 119  en:snacks, en:sweet-snacks, en:biscuits-and-ca...
# 137  en:snacks, en:sweet-snacks, en:biscuits-and-ca...
# 165
# 174  en:snacks, en:sweet-snacks, en:biscuits-and-ca...
# 190  en:snacks, en:sweet-snacks, en:biscuits-and-ca...
# 214
# 231
# 290  en:snacks, en:sweet-snacks, en:biscuits-and-ca...
# 296
# 323
# 674  en:snacks, en:sweet-snacks, en:biscuits-and-ca...
# 712  en:snacks, en:sweet-snacks, en:biscuits-and-ca...
#
#                                              countries  \
# 16                                           en:canada
# 26                                           en:canada
# 52                                           en:canada
# 119                                          en:canada
# 137                               en:canada, en:france
# 165                                          en:canada
# 174                                          en:canada
# 190                                          en:canada
# 214                                          en:canada
# 231                                          en:canada
# 290                                          en:canada
# 296                                          en:canada
# 323                                          en:canada
# 674  en:belgium, en:canada, en:france, en:germany, ...
# 712  en:belgium, en:canada, en:denmark, en:finland,...
#
#                                              image_url  \
# 16                                                 N/A
# 26                                                 N/A
# 52                                                 N/A
# 119  https://images.openfoodfacts.org/images/produc...
# 137  https://images.openfoodfacts.org/images/produc...
# 165  https://images.openfoodfacts.org/images/produc...
# 174  https://images.openfoodfacts.org/images/produc...
# 190  https://images.openfoodfacts.org/images/produc...
# 214  https://images.openfoodfacts.org/images/produc...
# 231  https://images.openfoodfacts.org/images/produc...
# 290  https://images.openfoodfacts.org/images/produc...
# 296  https://images.openfoodfacts.org/images/produc...
# 323  https://images.openfoodfacts.org/images/produc...
# 674  https://images.openfoodfacts.org/images/produc...
# 712  https://images.openfoodfacts.org/images/produc...
#
#                                       ingredients_text  energy_kcal_100g  \
# 16                                                 N/A        483.000000
# 26                                                 N/A        490.000000
# 52                                                 N/A        483.000000
# 119  Sugars (sugar and/or golden sugar, glucose-fru...        483.000000
# 137  sucres, farine de blé, huile de palme modifié,...        517.000000
# 165  wheat flour, sugars (sugar, glucose-fructose),...        500.000000
# 174  sugars (sugar, glucose-fructose), wheat flour,...        471.000000
# 190  Sucres (sucre, glucose-fructose), Farine de bl...        482.758621
# 214                                                N/A        470.588235
# 231                                                N/A        454.545455
# 290  sugar, rolled oats, peanut butter (peanuts, hy...        500.000000
# 296                                                N/A        482.758621
# 323                                                N/A        482.758600
# 674  Farine de BLE, sucre, huile de palme, huile de...        476.000000
# 712  Farine de BLÉ, sucre, huile de palme, huile de...        472.000000
#
#       fat_100g  saturated_fat_100g  ...  proteins_100g  salt_100g  \
# 16   24.100000            8.620000  ...       3.450000   0.517000
# 26   22.400000            0.000000  ...       6.120000   0.969000
# 52   20.700000            5.170000  ...       6.900000   1.080000
# 119  20.700000            6.900000  ...       3.450000   0.819000
# 137  24.100000            8.620000  ...       3.450000   0.647000
# 165  20.588235            5.882353  ...       2.941176   0.845588
# 174  20.600000            5.880000  ...       2.940000   0.810000
# 190  24.137931            8.620690  ...       3.448276   0.646552
# 214  20.588235            5.882353  ...       2.941176   0.955882
# 231  20.454545            4.545455  ...       4.545455   0.965909
# 290  20.588235            5.882353  ...       8.823529   0.477941
# 296  20.689655            6.896552  ...       3.448276   0.905172
# 323  24.137900            8.620700  ...       3.448300   0.775862
# 674  20.000000            5.400000  ...       5.300000   0.730000
# 712  19.000000            5.400000  ...       5.600000   0.760000
#
#      nutrition_grade  nova_group  ecoscore_grade  \
# 16           unknown         NaN            None
# 26           unknown         NaN            None
# 52           unknown         NaN            None
# 119                e         4.0            None
# 137                e         4.0            None
# 165          unknown         4.0            None
# 174                e         4.0            None
# 190                e         4.0            None
# 214          unknown         NaN            None
# 231          unknown         NaN            None
# 290                e         4.0            None
# 296          unknown         NaN            None
# 323          unknown         NaN            None
# 674                e         4.0            None
# 712                e         4.0            None
#
#                                                 labels  \
# 16
# 26
# 52
# 119                                      en:cocoa-life
# 137
# 165
# 174
# 190
# 214
# 231
# 290
# 296
# 323
# 674  en:vegetarian, en:cocoa-life, en:green-dot, fr...
# 712  en:vegetarian, en:cocoa-life, en:green-dot, en...
#
#                            allergens  \
# 16
# 26
# 52
# 119           en:gluten, en:soybeans
# 137           en:gluten, en:soybeans
# 165           en:gluten, en:soybeans
# 174           en:gluten, en:soybeans
# 190           en:gluten, en:soybeans
# 214
# 231
# 290            en:gluten, en:peanuts
# 296
# 323
# 674           en:gluten, en:soybeans
# 712  en:gluten, en:milk, en:soybeans
#
#                                              packaging   created_t  \
# 16                                                      1749775318
# 26                                                      1747798716
# 52                                                      1742678696
# 119                                                     1713221135
# 137                                                     1705355336
# 165                                                     1689551884
# 174                                                     1686521334
# 190                                                     1678147546
# 214                                                     1659275985
# 231                                                     1650765666
# 290                                                     1625241196
# 296                                                     1621472558
# 323                                                     1613691612
# 674  en:plastic, en:box, en:cardboard, en:non-corru...  1484774630
# 712  en:plastic, en:box, en:cardboard, en:non-corru...  1337033518
#
#     last_modified_t
# 16       1749847609
# 26       1747798829
# 52       1746812779
# 119      1749582173
# 137      1724709049
# 165      1748705049
# 174      1746498416
# 190      1746655946
# 214      1748606206
# 231      1748219869
# 290      1748317276
# 296      1748649124
# 323      1748394936
# 674      1749242004
# 712      1748860006
#
# [15 rows x 23 columns]

# %%
output_path = r"C:\Users\jverc\OneDrive\02.DataScienceOD\exports\oreo_canada.csv" # Update the output path as needed

df_oreo_canada.to_csv(output_path, index=False, encoding="utf-8")
